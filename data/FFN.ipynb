# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import sys

sys.path.append('../data')

from dataloader import *
from sklearn.metrics import accuracy_score

# %load_ext autoreload
# %autoreload 2

# %%
# Config variables
batch_size = 32
val_size = 0.1
test_size = 0.1

num_heads = 3
num_layers = 2
learning_rate = 0.0001

# %%
# Load the data into DataLoader
train_loader, val_loader, test_loader = get_dataloader(batch_size, val_size, test_size)
# Out:
# The number of negative values in target_HF column is: 12479
# The number of positive values in target_HF column is: 7917

# %%
class ResNet(nn.Module):
    def __init__(self, in_features, num_blocks=2, dropout_prob=0.1, hidden_size = 64):
        super(ResNet, self).__init__()
        self.linear = nn.Linear(in_features[0]*in_features[1], hidden_size)
        #self.blocks = nn.ModuleList([ResNetBlock(hidden_size, dropout_prob=dropout_prob) for _ in range(num_blocks)])
        self.fc1 = nn.Linear(hidden_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.dropout = nn.Dropout(p=dropout_prob)
        self.prediction = nn.Sequential(
            nn.BatchNorm1d(hidden_size),
            nn.ReLU(inplace=True),
            nn.Linear(hidden_size, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = x.view(x.size(0), -1)  # reshape x to (batch_size, 46 * 3)
        x = self.linear(x)
        x = self.fc1(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = self.dropout(x)
        x = self.prediction(x)
        return x.squeeze()

# %%
# Define the loss function
loss_fn = nn.BCELoss()

# Define the model
model = ResNet(in_features=(46,3), num_blocks=2, dropout_prob=0.1, hidden_size = 64)

# Define the optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Train the model
num_epochs = 100

train_losses = []
val_losses = []
train_accs = []
val_accs = []

for epoch in range(num_epochs):
    # Training loop
    train_loss = 0
    train_preds = []
    train_labels = []
    for batch in train_loader:
        batch_x = batch['patient']
        batch_y = batch['label']
        optimizer.zero_grad()
        outputs = model(batch_x)
        loss = loss_fn(outputs, batch_y.flatten())
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * batch_x.shape[0]
        preds = outputs > 0.5
        train_preds.extend(preds.tolist())
        train_labels.extend(batch_y.tolist())
    
    # Validation loop
    val_loss = 0
    val_preds = []
    val_labels = []
    with torch.no_grad():
        for batch in val_loader:
            batch_x = batch['patient']
            batch_y = batch['label']
            outputs = model(batch_x)
            loss = loss_fn(outputs, batch_y.flatten())
            val_loss += loss.item() * batch_x.shape[0]
            preds = outputs > 0.5
            val_preds.extend(preds.tolist())
            val_labels.extend(batch_y.tolist())
    val_acc = accuracy_score(val_labels, val_preds)
    train_acc = accuracy_score(train_labels, train_preds)
    
    # Append losses and accuracies to lists for plotting
    train_loss /= len(train_loader)*batch_size
    val_loss /= len(val_loader)*batch_size
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accs.append(train_acc)
    val_accs.append(val_acc)
    
    # Print epoch information
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, Train Acc: {train_acc:.4f}, Val Acc: {val_acc:.4f}")
# Out:
# Epoch 1/100, Train Loss: 0.6274, Val Loss: 0.5783, Train Acc: 0.6410, Val Acc: 0.7039
# Epoch 2/100, Train Loss: 0.5707, Val Loss: 0.5704, Train Acc: 0.7041, Val Acc: 0.7034
# Epoch 3/100, Train Loss: 0.5645, Val Loss: 0.5633, Train Acc: 0.7082, Val Acc: 0.7196
# Epoch 4/100, Train Loss: 0.5668, Val Loss: 0.5653, Train Acc: 0.7054, Val Acc: 0.7093
# Epoch 5/100, Train Loss: 0.5623, Val Loss: 0.5565, Train Acc: 0.7092, Val Acc: 0.7206
# Epoch 6/100, Train Loss: 0.5588, Val Loss: 0.5561, Train Acc: 0.7139, Val Acc: 0.7245
# Epoch 7/100, Train Loss: 0.5578, Val Loss: 0.5560, Train Acc: 0.7111, Val Acc: 0.7245
# Epoch 8/100, Train Loss: 0.5547, Val Loss: 0.5523, Train Acc: 0.7125, Val Acc: 0.7255
# Epoch 9/100, Train Loss: 0.5568, Val Loss: 0.5503, Train Acc: 0.7143, Val Acc: 0.7304
# Epoch 10/100, Train Loss: 0.5534, Val Loss: 0.5495, Train Acc: 0.7147, Val Acc: 0.7255
# Epoch 11/100, Train Loss: 0.5518, Val Loss: 0.5515, Train Acc: 0.7176, Val Acc: 0.7240
# Epoch 12/100, Train Loss: 0.5519, Val Loss: 0.5506, Train Acc: 0.7148, Val Acc: 0.7309
# Epoch 13/100, Train Loss: 0.5500, Val Loss: 0.5503, Train Acc: 0.7195, Val Acc: 0.7299
# Epoch 14/100, Train Loss: 0.5484, Val Loss: 0.5496, Train Acc: 0.7170, Val Acc: 0.7284
# Epoch 15/100, Train Loss: 0.5489, Val Loss: 0.5512, Train Acc: 0.7211, Val Acc: 0.7275
# Epoch 16/100, Train Loss: 0.5501, Val Loss: 0.5521, Train Acc: 0.7187, Val Acc: 0.7255
# Epoch 17/100, Train Loss: 0.5459, Val Loss: 0.5535, Train Acc: 0.7212, Val Acc: 0.7255
# Epoch 18/100, Train Loss: 0.5458, Val Loss: 0.5504, Train Acc: 0.7221, Val Acc: 0.7284
# Epoch 19/100, Train Loss: 0.5456, Val Loss: 0.5505, Train Acc: 0.7222, Val Acc: 0.7289
# Epoch 20/100, Train Loss: 0.5474, Val Loss: 0.5517, Train Acc: 0.7195, Val Acc: 0.7358
# Epoch 21/100, Train Loss: 0.5450, Val Loss: 0.5529, Train Acc: 0.7209, Val Acc: 0.7299
# Epoch 22/100, Train Loss: 0.5456, Val Loss: 0.5496, Train Acc: 0.7211, Val Acc: 0.7284
# Epoch 23/100, Train Loss: 0.5445, Val Loss: 0.5515, Train Acc: 0.7214, Val Acc: 0.7260
# Epoch 24/100, Train Loss: 0.5426, Val Loss: 0.5489, Train Acc: 0.7222, Val Acc: 0.7279
# Epoch 25/100, Train Loss: 0.5431, Val Loss: 0.5493, Train Acc: 0.7238, Val Acc: 0.7275
# Epoch 26/100, Train Loss: 0.5431, Val Loss: 0.5470, Train Acc: 0.7232, Val Acc: 0.7333
# Epoch 27/100, Train Loss: 0.5448, Val Loss: 0.5509, Train Acc: 0.7216, Val Acc: 0.7294
# Epoch 28/100, Train Loss: 0.5423, Val Loss: 0.5513, Train Acc: 0.7224, Val Acc: 0.7240
# Epoch 29/100, Train Loss: 0.5436, Val Loss: 0.5488, Train Acc: 0.7257, Val Acc: 0.7328
# Epoch 30/100, Train Loss: 0.5425, Val Loss: 0.5477, Train Acc: 0.7221, Val Acc: 0.7333
# Epoch 31/100, Train Loss: 0.5440, Val Loss: 0.5461, Train Acc: 0.7238, Val Acc: 0.7343
# Epoch 32/100, Train Loss: 0.5434, Val Loss: 0.5464, Train Acc: 0.7224, Val Acc: 0.7284
# Epoch 33/100, Train Loss: 0.5434, Val Loss: 0.5476, Train Acc: 0.7199, Val Acc: 0.7387
# Epoch 34/100, Train Loss: 0.5428, Val Loss: 0.5451, Train Acc: 0.7259, Val Acc: 0.7304
# Epoch 35/100, Train Loss: 0.5430, Val Loss: 0.5493, Train Acc: 0.7247, Val Acc: 0.7343
# Epoch 36/100, Train Loss: 0.5407, Val Loss: 0.5528, Train Acc: 0.7244, Val Acc: 0.7304
# Epoch 37/100, Train Loss: 0.5409, Val Loss: 0.5548, Train Acc: 0.7257, Val Acc: 0.7245
# Epoch 38/100, Train Loss: 0.5406, Val Loss: 0.5497, Train Acc: 0.7253, Val Acc: 0.7289
# Epoch 39/100, Train Loss: 0.5398, Val Loss: 0.5489, Train Acc: 0.7247, Val Acc: 0.7294
# Epoch 40/100, Train Loss: 0.5387, Val Loss: 0.5487, Train Acc: 0.7243, Val Acc: 0.7289
# Epoch 41/100, Train Loss: 0.5409, Val Loss: 0.5495, Train Acc: 0.7254, Val Acc: 0.7314
# Epoch 42/100, Train Loss: 0.5402, Val Loss: 0.5482, Train Acc: 0.7267, Val Acc: 0.7363
# Epoch 43/100, Train Loss: 0.5403, Val Loss: 0.5440, Train Acc: 0.7263, Val Acc: 0.7333
# Epoch 44/100, Train Loss: 0.5404, Val Loss: 0.5516, Train Acc: 0.7248, Val Acc: 0.7289
# Epoch 45/100, Train Loss: 0.5403, Val Loss: 0.5470, Train Acc: 0.7227, Val Acc: 0.7309
# Epoch 46/100, Train Loss: 0.5379, Val Loss: 0.5460, Train Acc: 0.7273, Val Acc: 0.7319
# Epoch 47/100, Train Loss: 0.5388, Val Loss: 0.5478, Train Acc: 0.7255, Val Acc: 0.7338
# Epoch 48/100, Train Loss: 0.5392, Val Loss: 0.5499, Train Acc: 0.7276, Val Acc: 0.7377
# Epoch 49/100, Train Loss: 0.5391, Val Loss: 0.5528, Train Acc: 0.7268, Val Acc: 0.7294
# Epoch 50/100, Train Loss: 0.5393, Val Loss: 0.5542, Train Acc: 0.7282, Val Acc: 0.7260
# Epoch 51/100, Train Loss: 0.5394, Val Loss: 0.5537, Train Acc: 0.7284, Val Acc: 0.7309
# Epoch 52/100, Train Loss: 0.5386, Val Loss: 0.5507, Train Acc: 0.7273, Val Acc: 0.7343
# Epoch 53/100, Train Loss: 0.5378, Val Loss: 0.5503, Train Acc: 0.7257, Val Acc: 0.7284
# Epoch 54/100, Train Loss: 0.5384, Val Loss: 0.5480, Train Acc: 0.7252, Val Acc: 0.7373
# Epoch 55/100, Train Loss: 0.5396, Val Loss: 0.5532, Train Acc: 0.7278, Val Acc: 0.7294
# Epoch 56/100, Train Loss: 0.5383, Val Loss: 0.5474, Train Acc: 0.7277, Val Acc: 0.7338
# Epoch 57/100, Train Loss: 0.5391, Val Loss: 0.5492, Train Acc: 0.7262, Val Acc: 0.7324
# Epoch 58/100, Train Loss: 0.5380, Val Loss: 0.5465, Train Acc: 0.7257, Val Acc: 0.7333
# Epoch 59/100, Train Loss: 0.5373, Val Loss: 0.5462, Train Acc: 0.7261, Val Acc: 0.7328
# Epoch 60/100, Train Loss: 0.5381, Val Loss: 0.5513, Train Acc: 0.7295, Val Acc: 0.7260
# Epoch 61/100, Train Loss: 0.5369, Val Loss: 0.5498, Train Acc: 0.7280, Val Acc: 0.7338
# Epoch 62/100, Train Loss: 0.5371, Val Loss: 0.5518, Train Acc: 0.7263, Val Acc: 0.7216
# Epoch 63/100, Train Loss: 0.5388, Val Loss: 0.5473, Train Acc: 0.7276, Val Acc: 0.7377
# Epoch 64/100, Train Loss: 0.5387, Val Loss: 0.5491, Train Acc: 0.7274, Val Acc: 0.7299
# Epoch 65/100, Train Loss: 0.5365, Val Loss: 0.5471, Train Acc: 0.7278, Val Acc: 0.7319
# Epoch 66/100, Train Loss: 0.5362, Val Loss: 0.5501, Train Acc: 0.7306, Val Acc: 0.7279
# Epoch 67/100, Train Loss: 0.5382, Val Loss: 0.5518, Train Acc: 0.7263, Val Acc: 0.7348
# Epoch 68/100, Train Loss: 0.5361, Val Loss: 0.5493, Train Acc: 0.7278, Val Acc: 0.7279
# Epoch 69/100, Train Loss: 0.5364, Val Loss: 0.5493, Train Acc: 0.7295, Val Acc: 0.7338
# Epoch 70/100, Train Loss: 0.5366, Val Loss: 0.5492, Train Acc: 0.7247, Val Acc: 0.7373
# Epoch 71/100, Train Loss: 0.5374, Val Loss: 0.5499, Train Acc: 0.7281, Val Acc: 0.7397
# Epoch 72/100, Train Loss: 0.5387, Val Loss: 0.5557, Train Acc: 0.7285, Val Acc: 0.7319
# Epoch 73/100, Train Loss: 0.5366, Val Loss: 0.5543, Train Acc: 0.7270, Val Acc: 0.7377
# Epoch 74/100, Train Loss: 0.5368, Val Loss: 0.5474, Train Acc: 0.7254, Val Acc: 0.7392
# Epoch 75/100, Train Loss: 0.5381, Val Loss: 0.5507, Train Acc: 0.7265, Val Acc: 0.7373
# Epoch 76/100, Train Loss: 0.5389, Val Loss: 0.5473, Train Acc: 0.7292, Val Acc: 0.7319
# Epoch 77/100, Train Loss: 0.5374, Val Loss: 0.5508, Train Acc: 0.7265, Val Acc: 0.7338
# Epoch 78/100, Train Loss: 0.5392, Val Loss: 0.5512, Train Acc: 0.7266, Val Acc: 0.7294
# Epoch 79/100, Train Loss: 0.5355, Val Loss: 0.5521, Train Acc: 0.7298, Val Acc: 0.7299
# Epoch 80/100, Train Loss: 0.5343, Val Loss: 0.5489, Train Acc: 0.7300, Val Acc: 0.7289
# Epoch 81/100, Train Loss: 0.5368, Val Loss: 0.5497, Train Acc: 0.7295, Val Acc: 0.7240
# Epoch 82/100, Train Loss: 0.5357, Val Loss: 0.5497, Train Acc: 0.7287, Val Acc: 0.7289
# Epoch 83/100, Train Loss: 0.5346, Val Loss: 0.5461, Train Acc: 0.7308, Val Acc: 0.7392
# Epoch 84/100, Train Loss: 0.5352, Val Loss: 0.5471, Train Acc: 0.7312, Val Acc: 0.7338
# Epoch 85/100, Train Loss: 0.5368, Val Loss: 0.5469, Train Acc: 0.7267, Val Acc: 0.7284
# Epoch 86/100, Train Loss: 0.5367, Val Loss: 0.5506, Train Acc: 0.7266, Val Acc: 0.7358
# Epoch 87/100, Train Loss: 0.5349, Val Loss: 0.5480, Train Acc: 0.7271, Val Acc: 0.7368
# Epoch 88/100, Train Loss: 0.5359, Val Loss: 0.5478, Train Acc: 0.7291, Val Acc: 0.7304
# Epoch 89/100, Train Loss: 0.5369, Val Loss: 0.5452, Train Acc: 0.7284, Val Acc: 0.7377
# Epoch 90/100, Train Loss: 0.5376, Val Loss: 0.5504, Train Acc: 0.7279, Val Acc: 0.7279
# Epoch 91/100, Train Loss: 0.5368, Val Loss: 0.5504, Train Acc: 0.7279, Val Acc: 0.7368
# Epoch 92/100, Train Loss: 0.5367, Val Loss: 0.5469, Train Acc: 0.7300, Val Acc: 0.7299
# Epoch 93/100, Train Loss: 0.5360, Val Loss: 0.5521, Train Acc: 0.7284, Val Acc: 0.7270
# Epoch 94/100, Train Loss: 0.5362, Val Loss: 0.5492, Train Acc: 0.7271, Val Acc: 0.7333
# Epoch 95/100, Train Loss: 0.5365, Val Loss: 0.5465, Train Acc: 0.7292, Val Acc: 0.7294
# Epoch 96/100, Train Loss: 0.5354, Val Loss: 0.5484, Train Acc: 0.7309, Val Acc: 0.7338
# Epoch 97/100, Train Loss: 0.5337, Val Loss: 0.5485, Train Acc: 0.7298, Val Acc: 0.7294
# Epoch 98/100, Train Loss: 0.5352, Val Loss: 0.5459, Train Acc: 0.7297, Val Acc: 0.7407
# Epoch 99/100, Train Loss: 0.5354, Val Loss: 0.5524, Train Acc: 0.7292, Val Acc: 0.7265
# Epoch 100/100, Train Loss: 0.5334, Val Loss: 0.5468, Train Acc: 0.7321, Val Acc: 0.7333

# %%
# Set the model to evaluation mode
model.eval()

# Test loop
test_loss = 0
test_preds = []
test_labels = []
with torch.no_grad():
    for batch in test_loader:
        batch_x = batch['patient']
        batch_y = batch['label']
        outputs = model(batch_x)
        loss = loss_fn(outputs, batch_y.flatten())
        test_loss += loss.item() * batch_x.shape[0]
        preds = outputs > 0.5 #torch.argmax(outputs, dim=1)
        test_preds.extend(preds.tolist())
        test_labels.extend(batch_y.tolist())
test_acc = accuracy_score(test_labels, test_preds)

# Print test results
test_loss /= len(test_loader)*batch_size
print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}")
# Out:
# Test Loss: 0.5358, Test Acc: 0.7294

# %%
import matplotlib.pyplot as plt

# Plot the losses and accuracies
epochs = np.arange(1, num_epochs+1)
plt.plot(epochs, train_losses, label='train')
plt.plot(epochs, val_losses, label='val')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(epochs, train_accs, label='train')
plt.plot(epochs, val_accs, label='val')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
